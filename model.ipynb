# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import acquire as a
from pathlib import Path 
import nlp_wrangle as w
import prepare as p
from sklearn.model_selection import train_test_split

# %%
df = a.acquire_spam_data()

# %%
df_cleaned = p.prep_spam_data(df,'text')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5572 entries, 0 to 5571
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              5572 non-null   int64
#  1   label           5572 non-null   object
#  2   text            5572 non-null   object
#  3   message_length  5572 non-null   int64
#  4   clean           5572 non-null   object
#  5   stemmed         5572 non-null   object
#  6   lemmatized      5572 non-null   object
# dtypes: int64(2), object(5)
# memory usage: 304.8+ KB

# %%
df_cleaned['stem_character_length'] = df['stemmed'].str.len()
df_cleaned['lemmatized_character_length'] = df['lemmatized'].str.len()
df_cleaned['clean_character_length'] = df['clean'].str.len()
df_cleaned['original_character_length'] = df['text'].str.len()
df_cleaned.head()
# Out:
# /var/folders/f1/m4_s2k_97xng0khbnvxb1jbw0000gn/T/ipykernel_83105/2200568501.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned['stem_character_length'] = df['stemmed'].str.len()
#   label                                               text  \
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...
#
#                                                clean  \
# 0  go jurong point crazy available bugis n great ...
# 1                            ok lar joking wif u oni
# ...

# %% [markdown]
# ## split data

# %%
# data split 20,25,55
train_validate, test = train_test_split(df_cleaned, test_size=.2,
                                       random_state=100,
                                       stratify=df_cleaned['label'])
train, validate = train_test_split(train_validate, test_size =.25,
                                  random_state=100,)

# %%
train
# Out:
#      label                                               text  \
# 5084   ham                              Hey happy birthday...
# 878   spam  U have a secret admirer who is looking 2 make ...
# 4934   ham  Hey babe, how's it going ? Did you ever figure...
# 4154  spam  Want a new Video Phone? 750 anytime any networ...
# 2126   ham           You do got a shitload of diamonds though
# ...    ...                                                ...
# 4724   ham  There'll be a minor shindig at my place later ...
# 4658   ham  I cant pick the phone right now. Pls send a me...
# 2602   ham                So when you gonna get rimac access
# 59     ham           Yes..gauti and sehwag out of odi series.
# 4704   ham                           Hey anyway i have to :-)
#
#                                                   clean  \
# 5084                                 hey happy birthday
# 878   u secret admirer looking 2 make contact ufind ...
# ...

# %% [raw]
# # questions
# Are the mean lengths of spam messages different than ham messages across the different word reduction tools?
